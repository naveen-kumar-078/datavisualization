# %%
import matplotlib.pyplot as plt

products = ['A', 'B', 'C', 'D']
sales = [120, 180, 90, 150]

plt.bar(products, sales)
plt.title("Sales by Product")
plt.xlabel("Products")
plt.ylabel("Sales")
plt.show()
