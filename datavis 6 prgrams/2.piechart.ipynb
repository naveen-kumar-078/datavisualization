# %%
import matplotlib.pyplot as plt

labels = ['Marketing', 'Development', 'HR', 'Finance']
budget = [35, 40, 10, 15]

plt.pie(budget, labels=labels, autopct='%1.1f%%')
plt.title("Budget Allocation")
plt.show()
