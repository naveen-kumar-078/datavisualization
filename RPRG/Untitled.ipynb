# %%
a <- "nak"
cat(paste(a))
# Out:
# nak

# %%
data <- read.csv("synthetic_dataset.csv")

# %%
head(data)
View(data)
# Out:
#   Category Price Rating   Stock        Discount
# 1          5548  1.870322               0
# 2          3045  4.757798              38
# 3          4004        NA In Stock      0
# 4          4808  1.492085              33
# 5          1817        NA Out of Stock 23
# 6          3522        NA              NA
#      Category Price Rating   Stock        Discount
# 1             5548  1.870322               0
# 2             3045  4.757798              38
# 3             4004        NA In Stock      0
# 4             4808  1.492085              33
# 5             1817        NA Out of Stock 23
# 6             3522        NA              NA
# 7    C         667  3.668341 In Stock     41
# 8    A        7125  4.983998 Out of Stock  7
# 9    A        2777  2.678384 In Stock      6
# 10             463  4.626187               3
# 11   A        1151  2.947838              NA
# 12   A        3772  4.890750 In Stock     45
# 13            7719  2.982242 In Stock      4
# ...

# %%
data
# Out:
#      Category Price Rating   Stock        Discount
# 1             5548  1.870322               0
# 2             3045  4.757798              38
# 3             4004        NA In Stock      0
# 4             4808  1.492085              33
# 5             1817        NA Out of Stock 23
# 6             3522        NA              NA
# 7    C         667  3.668341 In Stock     41
# 8    A        7125  4.983998 Out of Stock  7
# 9    A        2777  2.678384 In Stock      6
# 10             463  4.626187               3
# 11   A        1151  2.947838              NA
# 12   A        3772  4.890750 In Stock     45
# 13            7719  2.982242 In Stock      4
# 14   C        8416  1.270943              29
# 15   B        8530        NA              10
# 16   A        7936  3.032832 In Stock     44
# 17   B        9319  3.479064 In Stock     28
# 18              NA  4.097464              40
# 19   D        2066        NA              30
# 20   B        1784        NA              12
# ...

# %%
data$
